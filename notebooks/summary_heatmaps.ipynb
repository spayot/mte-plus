# %% [markdown]
# # Summary Heatmaps
# The Goal of this notebook is to generate summary heatmaps that allow to visualize the impact on performance of various categorical transformations and classifier pairs, for various classification tasks.

# %%
import os
import sys

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sys.path.append('../src')
import columnar as col

# %load_ext autoreload
# %autoreload 2

ROOT_PATH = '../'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cfg = col.config.BenchmarkConfig.load('../config.yml')

tasks = ['petfinder', 'adults', 'mushrooms', 'titanic', 'hr_analytics']

col.plot.generate_heatmaps(tasks, metric='auc', 
                           reports_path=os.path.join(ROOT_PATH, cfg.paths.reports),
                           figures_path=os.path.join(ROOT_PATH, cfg.paths.figures)
                          )

# %%
reporter = col.Reporter.from_csv('../reports/hr_analytics.csv')
fig = col.plot_model_encoder_pairs(reporter=reporter,
                             metrics= None,
                             figpath = '../figures/hr_analytics.png',
                             title= None,
                             show = True,
                            )
